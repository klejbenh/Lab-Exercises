# %%
import turtle #Importing turtle
import random

tina = turtle.Turtle()
tina.shape("turtle")
tony = tina.clone() #Made 2 turtles here and used clone function to clone new turtle 

#prompt user for color and make turtle and turtle background that color
turtle_color = input("What color should tina the turtle be?")
turtle_color_2 = input("What color should tony the turtle be?")
tina.color(turtle_color)
tony.color(turtle_color_2)
myscreen = turtle.Screen()
background_color = input("What color should background be?")
myscreen.bgcolor(background_color)

tina.penup() 
tony.penup()
tina.goto(-200,0)
tony.goto(200,0)
tina.pendown()
tony.pendown()#Move tina and tony to two different quadrants

sizes = [1,2,3,4,5]
size = random.choice(sizes) #Making random sizes for penzise that will be used for the shapes

def triangle(): #Here I am making definitions using for loops for all of the sizes that wil be graphed
    for tort in range(3):
        tina.pensize(size)
        tina.forward(75)
        tina.left(360/3)

def square():
    for tort in range(4):
        tina.pensize(size)
        tina.forward(100)
        tina.left(360/4)
        
def pentagon(): 
    for tort in range(5):
        tina.pensize(size)
        tina.forward(200)
        tina.left(360/5)

def hexagon():
    for tort in range(6):
        tony.pensize(size)
        tony.forward(100)
        tony.left(360/6)

def heptagon():
    for tort in range(7):
        tony.pensize(size)
        tony.forward(75)
        tony.left(360/7)
    
answer = input('Choose a shape! Triangle, Square or Pentagon!').lower() #Asking user to choose shape tina will graph
if answer ==('triangle'):
    triangle()

elif answer == ('square'):
    square()

elif answer == ('pentagon'):
    pentagon()

else:
    print ('Input is wrong')


second_answer = input('Choose another shape shape! Circle, Hexagon or Heptagon!').lower() #Asking user to choose shape tony will graph
if second_answer == ('circle'):
    tony.circle(100)

elif second_answer == ('hexagon'):
    hexagon()

elif second_answer == ('heptagon'):
    heptagon()
else:
    print('Input is wrong')

# %%
#turtle game - cross the finish line 
import turtle
import random

p1 = turtle.Turtle()
p1.color("green")
p1.shape("turtle")
p2 = p1.clone() #can clone our turtles!
p2.color("purple") #set a new color

#creating a finish line
p1.color('yellow')
p1.penup()
p1.goto(350, 300)
p1.right(90)
p1.pendown()
p1.forward(500)
p1.left(90)
p1.penup()
p1.color('cyan')

#creating my starting point
p1.goto(-200, 100)
p2.penup()
p2.goto(-200, -100)

#creating a die
die = [1, 2, 3, 4, 5, 6]

for i in range(20):
    p1_turn = input("Press Enter to roll the dice")
    die_result = random.choice(die)
    movement = die_result*20
    print(f"The result of the die roll is {die_result}. Your turtle will move {movement} steps.")
    p1.forward(movement)
    
    if p1.pos() >= (350, 100): #.pos() finds the position
        print("Player One Wins!")
        p1.circle(40)
        break
    elif p2.pos() >= (350, -100):
        print("Player Two Wins!")
        p2.circle(40)
        break
    else:
        p2_turn = input("Press Enter to roll the dice")
        die_result = random.choice(die)
        movement = die_result*20
        print(f"The result of the die roll is {die_result}. Your turtle will move {movement} steps.")
        p2.forward(movement)

# %%
This one below will be what I work on

# %%
#How will I get through both players getting it wrong?
import turtle
import random

background = turtle.Screen() #Making background color black, I learned this from https://docs.python.org/3/library/turtle.html
background.bgcolor('black')
p1 = turtle.Turtle()
p1.shape("turtle")#Creating 2 turtles and making them different colors then placing them on different sides
p1.color("cyan")
p2 = p1.clone() #Turtles can be cloned and this is much easier than figuring out how to make a new one
p2.color("green") #set a new color
p2.pencolor('green')

#creating a finish line
p1.color('yellow')
p1.penup()
p1.goto(-325,300)
p1.pendown()
p1.forward(650)

p1.penup()#Making P1 go to start position
p1.color('cyan')
p1.goto(-200,-380)
p1.pendown()

p2.penup() #Start point of second turtle
p2.goto(200,-380)
p2.pendown() #This will be like 75 lines long, I need to decide if I will use it for game project or presentation              

shapes = ['pentagon','hexagon','heptagon','octagon','nonagon','decagon','pentagon1','hexagon1','heptagon1','octagon1','nonagon1','decagon1']
print('Welcome to a chance and knowledge based game that tests your geometry skills! In this game you will be given a shape and you will have to tell me something about it. :)')

for tort in range(25):
    question = random.choice(shapes)

    if p1.ycor() >= (300): #Position function should give me current position of turtle but I am having issues
        print("Player One Wins! Congragulations!")#https://docs.python.org/3/library/turtle.html FINALLY THIS SOLVED IT
        p1.pensize(10)# .ycor() IS WHAT SOLVED MY WORRIES BRO HOOOOLLLLYYYYYYY
        p1.penup()
        p1.goto(-60,20)
        p1.pendown()
        for tort in range(2): #This for loop draws out the letter W
            p1.right(70)
            p1.forward(30)
            p1.left(140)
            p1.forward(30)
            p1.right(70)

        p1.penup() #This little segment draws out the letter I
        p1.forward(20)
        p1.pendown()
        p1.right(90)
        p1.forward(28)

        p1.penup() #This little segment draws out the letter N
        p1.left(90)
        p1.forward(20)
        p1.left(90)
        p1.pendown()
        p1.forward(28)
        p1.right(150)
        p1.forward(33)
        p1.left(150)
        p1.forward(28)
        p1.penup()
        
        p1.goto(51,5) #This goes to the end of the N and then draws a circle to highlight WIN then puts the turtle where the dot on the I would be
        p1.pendown()
        p1.circle(60)
        p1.penup()
        p1.goto(1,40)
        break #Stops the game if this is achieved.
     
    elif p2.ycor() >= (300):#Position over here is also very sketchy, I have no clue how to do it correctly
        print("Player Two Wins! Congragulations!") #This elif is the same thing as above just for player 2, if they win that is
        p2.pensize(10)
        p2.penup()
        p2.goto(-60,20)
        p2.pendown()
        for tort in range(2):
            p2.right(70)
            p2.forward(30)
            p2.left(140)
            p2.forward(30)
            p2.right(70)

        p2.penup()
        p2.forward(20)
        p2.pendown()
        p2.right(90)
        p2.forward(28)

        p2.penup()
        p2.left(90)
        p2.forward(20)
        p2.left(90)
        p2.pendown()
        p2.forward(28)
        p2.right(150)
        p2.forward(33)
        p2.left(150)
        p2.forward(28)
        p2.penup()

        p2.goto(51,5)
        p2.pendown()
        p2.circle(60)
        p2.penup()
        p2.goto(1,40)
        break #Stops the code here too 
    
    
    elif question == 'pentagon': #Here I am 
        answer = input('Player 1, how many sides does a pentagon have?').lower()
        if answer == 'five':
            print('Correct!')
            for tort in range(5): #For loop creates a pentagon for me
                p1.pensize(3)
                p1.forward(50)
                p1.left(360/5)
        
            p1.penup() #After the shape is done drawing I move the turtle 100 up so as to stack the other shapes on top
            p1.left(90)
            p1.forward(100)
            p1.right(90)
            p1.pendown()
            
        else: #If the first player gets the question wrong the second player gets a chance at the same shape but different question.
            print("Incorrect! Player 2's turn!")
            answer1 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with five sides?')) 
            if answer1 == 72:
                print('Correct!')
                for tort in range(5):
                    p2.pensize(3)
                    p2.forward(50)
                    p2.left(360/5)
                
                p2.penup()
                p2.left(90)
                p2.forward(100)
                p2.right(90)
                p2.pendown()
                
            elif answer1 != 72: #If the second player does not give the correct answer then we just say both players got it wrong and continue the iterations of the loop
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
        
        
        
   #Everything from here down is pretty much the same as the lines above, all I changed was some variables, the for loops      
        
        
        
        
    elif question == 'hexagon':
        answer2 = input('Player 1, how many sides does a hexagon have?').lower()
        if answer2 == 'six':
            print('Correct!')
            for tort in range(6):
                p1.pensize(3)
                p1.forward(50)
                p1.left(360/6)
            p1.penup()
            p1.left(90)
            p1.forward(110)
            p1.right(90)
            p1.pendown()
            continue
            
        else:
            print("Incorrect! Player 2's turn!")
            answer3 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with six sides?'))
            if answer3 == 60:
                print('Correct!')
                
                for tort in range(6):
                    p2.pensize(3)
                    p2.forward(50) 
                    p2.left(360/6)
                
                p2.penup()
                p2.left(90)
                p2.forward(110)
                p2.right(90)
                p2.pendown()
            
            elif answer3 != 60:
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                
                
                
    elif question == 'heptagon':
        answer4 = input('Player 1, how many sides does a heptagon have?').lower()
        if answer4 == 'seven':
            print('Correct!')
            for tort in range(7):
                p1.pensize(3)
                p1.forward(50) 
                p1.left(360/7)
            p1.penup()
            p1.left(90)
            p1.forward(130)
            p1.right(90)
            p1.pendown()
            
        else:
            print("Incorrect! Player 2's turn!")
            answer5 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with seven sides? Make sure to round!'))
            if answer5 == 51:
                print('Correct!')
                
                for tort in range(7):
                    p2.pensize(3)
                    p2.forward(50) 
                    p2.left(360/7)
                
                p2.penup()
                p2.left(90)
                p2.forward(130)
                p2.right(90)
                p2.pendown()
            
            elif answer5 != 51:
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
                
                
    elif question == 'octagon':
        answer6 = input('Player 1, how many sides does a octagon have?').lower()
        if answer6 == 'eight':
            print('Correct!')
            for tort in range(8):
                p1.pensize(3)
                p1.forward(50) 
                p1.left(360/8)
            p1.penup()
            p1.left(90)
            p1.forward(145)
            p1.right(90)
            p1.pendown()
            
        else:
            print("Incorrect! Player 2's turn!")
            answer7 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with eight sides?'))
            if answer7 == 45:
                print('Correct!')
                
                for tort in range(8):
                    p2.pensize(3)
                    p2.forward(50) #make this smaller too
                    p2.left(360/8)
                
                p2.penup()
                p2.left(90)
                p2.forward(145)
                p2.right(90)
                p2.pendown()
            
            elif answer7 != 45:
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
                
                
    elif question == 'nonagon':
        answer7 = input('Player 1, how many sides does a nonagon have?').lower()
        if answer7 == 'nine':
            print('Correct!')
            for tort in range(9):
                p1.pensize(3)
                p1.forward(50) 
                p1.left(360/9)
            p1.penup()
            p1.left(90)
            p1.forward(160)
            p1.right(90)
            p1.pendown()
            
        else:
            print("Incorrect! Player 2's turn!")
            answer8 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with nine sides?'))#Remember to put.lower() here
            if answer8 == 40:
                print('Correct!')
                
                for tort in range(9):
                    p2.pensize(3)
                    p2.forward(50) #make this smaller too
                    p2.left(360/9)
                
                p2.penup()
                p2.left(90)
                p2.forward(160)
                p2.right(90)
                p2.pendown()
            
            elif answer8 != 40:
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
                
                
    elif question == 'decagon':
        answer9 = input('Player 1, how many sides does a decagon have?').lower()
        if answer9 == 'ten':
            print('Correct!')
            for tort in range(10):
                p1.pensize(3)
                p1.forward(50) 
                p1.left(360/10)
            p1.penup()
            p1.left(90)
            p1.forward(175)
            p1.right(90)
            p1.pendown()
            
        else:
            print("Incorrect! Player 2's turn!")
            answer10 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with ten sides?'))#Remember to put.lower() here
            if answer10 == 36:
                print('Correct!')
                
                for tort in range(10):
                    p2.pensize(3)
                    p2.forward(50) #make this smaller too
                    p2.left(360/10)
                
                p2.penup()
                p2.left(90)
                p2.forward(175)
                p2.right(90)
                p2.pendown()
            
            elif answer10 != 36:
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
                
                
                
                   
                
  #Here marks the second part where the second player also gets 50% shot at getting a question. The only real difference between the above if/elif statements is that the second player gets the question asked first now.              
                
                
            
                
    elif question == 'pentagon1':
        answer11 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with five sides?'))#.lower() here too 
        if answer11 == 72:
            print('Correct!')
            for tort in range(5):
                p2.pensize(3)
                p2.forward(50)
                p2.left(360/5)
                
            p2.penup()
            p2.left(90)
            p2.forward(100)
            p2.right(90)
            p2.pendown()
        
            
        else:
            print("Incorrect! Player 1's turn!")
            answer12 = input('Player 1, how many sides does a pentagon have?').lower()
            if answer12 == 'five':
                print('Correct!')
                for tort in range(5):
                    p1.pensize(3)
                    p1.forward(50)
                    p1.left(360/5)
        
                p1.penup()
                p1.left(90)
                p1.forward(100)
                p1.right(90)
                p1.pendown()
                
            elif answer12 != 'five':
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue 
                
        
    elif question == 'hexagon1':
        answer13 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with six sides?'))#.lower() here too 
        if answer13 == 60:
            print('Correct!')
            for tort in range(6):
                p2.pensize(3)
                p2.forward(50)
                p2.left(360/6)
                
            p2.penup()
            p2.left(90)
            p2.forward(110)
            p2.right(90)
            p2.pendown()
        
        else:
            print("Incorrect! Player 1's turn!")
            answer14 = input('Player 1, how many sides does a hexagon have?').lower()
            if answer14 == 'six':
                print('Correct!')
                for tort in range(6):
                    p1.pensize(3)
                    p1.forward(50)
                    p1.left(360/6)
        
                p1.penup()
                p1.left(90)
                p1.forward(110)
                p1.right(90)
                p1.pendown()
                
            elif answer14 != 'six':
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
                
                
    elif question == 'heptagon1':
        answer15 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with seven sides? Make sure to round!'))#.lower() here too 
        if answer15 == 51:
            print('Correct!')
            for tort in range(7):
                p2.pensize(3)
                p2.forward(50)
                p2.left(360/7)
                
            p2.penup()
            p2.left(90)
            p2.forward(130)
            p2.right(90)
            p2.pendown()
            
        else:
            print("Incorrect! Player 1's turn!")
            answer16 = input('Player 1, how many sides does a heptagon have?').lower()
            if answer16 == 'seven':
                print('Correct!')
                for tort in range(7):
                    p1.pensize(3)
                    p1.forward(50)
                    p1.left(360/7)
        
                p1.penup()
                p1.left(90)
                p1.forward(130)
                p1.right(90)
                p1.pendown()
                
            elif answer16 != 'seven':
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
                
                
    elif question == 'octagon1':
        answer15 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with eight sides?'))
        if answer15 == 45:
            print('Correct!')
            for tort in range(8):
                p2.pensize(3)
                p2.forward(50)
                p2.left(360/8)
                
            p2.penup()
            p2.left(90)
            p2.forward(145)
            p2.right(90)
            p2.pendown()
            
        else:
            print("Incorrect! Player 1's turn!")
            answer16 = input('Player 1, how many sides does a octagon have?').lower()
            if answer16 == 'eight':
                print('Correct!')
                for tort in range(8):
                    p1.pensize(3)
                    p1.forward(50)
                    p1.left(360/8)
        
                p1.penup()
                p1.left(90)
                p1.forward(145)
                p1.right(90)
                p1.pendown()
                
            elif answer16 != 'eight':
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
                
                
    elif question == 'nonagon1':
        answer17 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with nine sides?'))
        if answer17 == 40:
            print('Correct!')
            for tort in range(9):
                p2.pensize(3)
                p2.forward(50)
                p2.left(360/9)
                
            p2.penup()
            p2.left(90)
            p2.forward(160)
            p2.right(90)
            p2.pendown()
            
        else:
            print("Incorrect! Player 1's turn!")
            answer18 = input('Player 1, how many sides does a nonagon have?').lower()
            if answer18 == 'nine':
                print('Correct!')
                for tort in range(9):
                    p1.pensize(3)
                    p1.forward(50)
                    p1.left(360/9)
        
                p1.penup()
                p1.left(90)
                p1.forward(160)
                p1.right(90)
                p1.pendown()
                
            elif answer18 != 'nine':
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
                
                
    elif question == 'decagon1':
        answer19 = int(input('Player 2, what is the value in degrees of one exterior angle of a polygon with ten sides?'))
        if answer19 == 36:
            print('Correct!')
            for tort in range(10):
                p2.pensize(3)
                p2.forward(50)
                p2.left(360/10)
                
            p2.penup()
            p2.left(90)
            p2.forward(175)
            p2.right(90)
            p2.pendown()
            
        else:
            print("Incorrect! Player 1's turn!")
            answer20 = input('Player 1, how many sides does a decagon have?').lower()
            if answer20 == 'ten':
                print('Correct!')
                for tort in range(10):
                    p1.pensize(3)
                    p1.forward(50)
                    p1.left(360/10)
        
                p1.penup()
                p1.left(90)
                p1.forward(175)
                p1.right(90)
                p1.pendown()
                
            elif answer20 != 'ten':
                print("Incorrect! Since both players got the question wrong we will move onto a new one.")
                continue
# Out:
# Welcome to a chance and knowledge based game that tests your geometry skills! In this game you will be given a shape and you will have to tell me something about it. :)
# Player 1, how many sides does a nonagon have?nine
# Correct!
# Player 2, what is the value in degrees of one exterior angle of a polygon with seven sides? Make sure to round!52
# Incorrect! Player 1's turn!
# Player 1, how many sides does a heptagon have?seven
# Correct!

# %%
import turtle
p1 = turtle.Turtle()
p1.shape('turtle')

print("Player One Wins!")
p1.pensize(10)
p1.penup()
p1.goto(-40,20)
p1.pendown()
for tort in range(2):
    p1.right(70)
    p1.forward(30)
    p1.left(140)
    p1.forward(30)
    p1.right(70)

p1.penup()
p1.forward(20)
p1.pendown()
p1.right(90)
p1.forward(28)

p1.penup()
p1.left(90)
p1.forward(20)
p1.left(90)
p1.pendown()
p1.forward(28)
p1.right(150)
p1.forward(33)
p1.left(150)
p1.forward(28)
p1.penup()

# %%
#Issues with the code
#Position function not working for final goal line
#Creating a function was way too complex
#How to account for both players getting it wrong
#Indentation was a nightmare
#Many new variable names
#I wanted something that had the random function into it and two players
#A lot of trial and error when making the win function because I have no idea how to find the values I wanted exactly so I would just go up by incriments of 1 or five.

# %%
#Write a shitty first draft and let that be okay. In essays or dissertations just set aside 5 minutes to think and write bro.

# %%
import turtle #Importing turtle
import random

tina = turtle.Turtle()
tina.shape("turtle")

#prompt user for color and make turtle and turtle background that color
turtle_color = input("What color should tina the turtle be?")
tina.color(turtle_color)
myscreen = turtle.Screen()
background_color = input("What color should background be?")
myscreen.bgcolor(background_color)

tina.penup() 
tina.goto(-200,0)
tina.pendown()

sizes = [1,2,3,4,5]
size = random.choice(sizes) #Making random sizes for penzise that will be used for the shapes

def triangle(): #Here I am making definitions using for loops for all of the sizes that wil be graphed
    for tort in range(3):
        tina.pensize(size)
        tina.forward(75)
        tina.left(360/3)

def square():
    for tort in range(4):
        tina.pensize(size)
        tina.forward(100)
        tina.left(360/4)
        
def pentagon(): 
    for tort in range(5):
        tina.pensize(size)
        tina.forward(200)
        tina.left(360/5)
        
answer = input('Choose a shape! Triangle, Square or Pentagon!').lower() #Asking user to choose shape tina will graph
if answer ==('triangle'):
    triangle()

elif answer == ('square'):
    square()

elif answer == ('pentagon'):
    pentagon()

else:
    print ('Input is wrong')

# %%
while position == 'true':
